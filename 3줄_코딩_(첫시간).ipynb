# %% [markdown]
# <a href="https://colab.research.google.com/github/dscoool/waterai/blob/main/3%EC%A4%84_%EC%BD%94%EB%94%A9_(%EC%B2%AB%EC%8B%9C%EA%B0%84).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 코딩의 세계에 오신 것을 환영합니다!!
#
# 먼저 3줄을 차근차근히 입력해 봅시다!!
#
# 입력하고 좌측 PLAY 버튼 클릭!!
#
# ## 실습을 할 때 주의할 점 - 반드시 손으로 코드를 일일히 타이핑해서 입력해 보고, CTRL C + V 를 사용하지 마세요!! </br>
# ### **코드를 복붙하면 실력이 늘지 않습니다!! </br>
# 단, http 주소 등은 복사, 붙여넣기 해도 되어요.

# %% [markdown]
# # 판다스 - 데이터 처리, CSV 파일 입출력 라이브러리를 불러옵니다. (e.g. pd.read_csv)

# %%
import pandas as pd

# %% [markdown]
# # 원본 파일의 url을 통해 파일을 불러옵니다.

# %%
data = pd.read_csv("https://raw.githubusercontent.com/dscoool/waterai/main/water_potability.csv")

# %% [markdown]
#  # 데이터를 저장하고 있는 변수, 'data'를 입력하고 실행해 봅시다!!

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %%
data
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# ...

# %% [markdown]
# 3줄 코딩을 완료했습니다.
#
# 파이썬의 세계에 오신 것을 환영합니다!!
